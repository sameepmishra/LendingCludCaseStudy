# %%
#Load the libraryss
import pandas as pd #To work with dataset
import numpy as np #Math library
import seaborn as sns #Graph library that use matplot in background
import matplotlib.pyplot as plt #to plot some parameters in seaborn

plt.rcParams["figure.figsize"]=15,15 #This to increase the visual output screensize.

# %%
#Importing the data
RawData = pd.read_csv("loan.csv",index_col=0)
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_16768\3976808304.py:2: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   RawData = pd.read_csv("loan.csv",index_col=0)

# %%
#To View the Raw view of the data
RawData
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000           4975.0   36 months
# 1077430    1314167       2500         2500           2500.0   60 months
# 1077175    1313524       2400         2400           2400.0   36 months
# 1076863    1277178      10000        10000          10000.0   36 months
# 1075358    1311748       3000         3000           3000.0   60 months
# ...            ...        ...          ...              ...         ...
# 92187        92174       2500         2500           1075.0   36 months
# 90665        90607       8500         8500            875.0   36 months
# 90395        90390       5000         5000           1325.0   36 months
# 90376        89243       5000         5000            650.0   36 months
# 87023        86999       7500         7500            800.0   36 months
#
#         int_rate  installment grade sub_grade                   emp_title  \
# id
# ...

# %%
RawData.head()
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000           4975.0   36 months
# 1077430    1314167       2500         2500           2500.0   60 months
# 1077175    1313524       2400         2400           2400.0   36 months
# 1076863    1277178      10000        10000          10000.0   36 months
# 1075358    1311748       3000         3000           3000.0   60 months
#
#         int_rate  installment grade sub_grade                 emp_title  \
# id
# 1077501   10.65%       162.87     B        B2                       NaN
# 1077430   15.27%        59.83     C        C4                     Ryder
# 1077175   15.96%        84.33     C        C5                       NaN
# 1076863   13.49%       339.31     C        C1       AIR RESOURCES BOARD
# 1075358   12.69%        67.79     B        B5  University Medical Group
#
#         emp_length home_ownership  annual_inc verification_status issue_d  \
# id
# ...

# %%
#Lets clean up blank colums

RawData.dropna(how='all', axis=1, inplace=True)

#Increase the display windows size
pd.set_option('display.max_columns', None)

RawData.head()
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000           4975.0   36 months
# 1077430    1314167       2500         2500           2500.0   60 months
# 1077175    1313524       2400         2400           2400.0   36 months
# 1076863    1277178      10000        10000          10000.0   36 months
# 1075358    1311748       3000         3000           3000.0   60 months
#
#         int_rate  installment grade sub_grade                 emp_title  \
# id
# 1077501   10.65%       162.87     B        B2                       NaN
# 1077430   15.27%        59.83     C        C4                     Ryder
# 1077175   15.96%        84.33     C        C5                       NaN
# 1076863   13.49%       339.31     C        C1       AIR RESOURCES BOARD
# 1075358   12.69%        67.79     B        B5  University Medical Group
#
#         emp_length home_ownership  annual_inc verification_status issue_d  \
# id
# ...

# %%
# Filter the Loan_Status data to Current as we need to evaluate the data of Current
RawData_Current = RawData.loc[RawData['loan_status'] == 'Current']
RawData_Current
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1075358    1311748       3000         3000       3000.00000   60 months
# 1065420    1299514      10000        10000       9975.00000   60 months
# 1069346    1304237      12500        12500      12475.00000   60 months
# 1063958    1297940      14000        14000      13975.00000   60 months
# 1068575    1303001      15300        15300      15275.00000   60 months
# ...            ...        ...          ...              ...         ...
# 725556      920821      10400        10400      10400.00000   60 months
# 738420      935790       6000         6000       6000.00000   60 months
# 733695      930086      19200        19200      18847.76292   60 months
# 728422      924106       9350         9350       9350.00000   60 months
# 702171      894029       9000         9000       9000.00000   60 months
#
#         int_rate  installment grade sub_grade  \
# id
# ...

# %%
#Filtering Colums which seems valuable for evaluation
RawData_Current_filter = RawData_Current.filter(['loan_amnt','funded_amnt_inv','term','grade','int_rate','installment','emp_title','emp_length','home_ownership','annual_inc','verification_status','issue_d','purpose','title','addr_state','dti','earliest_cr_line','inq_last_6mths','earliest_cr_line','open_acc','revol_util','total_acc','out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int','last_pymnt_d','last_pymnt_amnt','last_credit_pull_d'], axis=1)
RawData_Current_filter
# Out:
#          loan_amnt  funded_amnt_inv        term grade int_rate  installment  \
# id
# 1075358       3000       3000.00000   60 months     B   12.69%        67.79
# 1065420      10000       9975.00000   60 months     C   15.96%       242.97
# 1069346      12500      12475.00000   60 months     B   12.69%       282.44
# 1063958      14000      13975.00000   60 months     D   17.27%       349.98
# 1068575      15300      15275.00000   60 months     F   22.06%       423.10
# ...            ...              ...         ...   ...      ...          ...
# 725556       10400      10400.00000   60 months     E    6.00%       218.99
# 738420        6000       6000.00000   60 months     B   10.37%       128.58
# 733695       19200      18847.76292   60 months     B   10.74%       414.97
# 728422        9350       9350.00000   60 months     B   10.00%       198.66
# 702171        9000       9000.00000   60 months     C   13.06%       205.06
#
# ...

# %%
#Filtering Colums which seems valuable for evaluation in Raw Data
RawData_filter = RawData.filter(['loan_status','loan_amnt','funded_amnt_inv','term','grade','int_rate','installment','emp_title','emp_length','home_ownership','annual_inc','verification_status','issue_d','purpose','title','addr_state','dti','earliest_cr_line','inq_last_6mths','earliest_cr_line','open_acc','revol_util','total_acc','out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int','last_pymnt_d','last_pymnt_amnt','last_credit_pull_d'], axis=1)
RawData_filter
# Out:
#          loan_status  loan_amnt  funded_amnt_inv        term grade int_rate  \
# id
# 1077501   Fully Paid       5000           4975.0   36 months     B   10.65%
# 1077430  Charged Off       2500           2500.0   60 months     C   15.27%
# 1077175   Fully Paid       2400           2400.0   36 months     C   15.96%
# 1076863   Fully Paid      10000          10000.0   36 months     C   13.49%
# 1075358      Current       3000           3000.0   60 months     B   12.69%
# ...              ...        ...              ...         ...   ...      ...
# 92187     Fully Paid       2500           1075.0   36 months     A    8.07%
# 90665     Fully Paid       8500            875.0   36 months     C   10.28%
# 90395     Fully Paid       5000           1325.0   36 months     A    8.07%
# 90376     Fully Paid       5000            650.0   36 months     A    7.43%
# 87023     Fully Paid       7500            800.0   36 months     E   13.75%
#
# ...

# %%
# Updating column values from text to numbers

## Removing Months from term column
RawData_Current_filter['term'] = (RawData_Current_filter['term'].replace({'months':''}, regex=True))

## Removing non number charactors from emp_length column
#RawData_Current_filter['emp_length'] = RawData_Current_filter['emp_length'].replace({'10+':'10.5'},regex=True)
RawData_Current_filter['emp_length'] = RawData_Current_filter['emp_length'].replace({'< 1':'0.5'},regex=True)
RawData_Current_filter['emp_length'] = RawData_Current_filter['emp_length'].replace({'year':''},regex=True)
RawData_Current_filter['emp_length'] = RawData_Current_filter['emp_length'].replace({'s':''},regex=True)

## Removing non number charactors from int_rate & revol_util columns
RawData_Current_filter['int_rate'] = RawData_Current_filter['int_rate'].replace({'%':''},regex=True)
RawData_Current_filter['revol_util'] = RawData_Current_filter['revol_util'].replace({'%':''},regex=True)

#RawData_Current_filter

# Updating column values from text to numbers in RawData with Loan_Status 

## Removing Months from term column
RawData_filter['term'] = (RawData_filter['term'].replace({'months':''}, regex=True))

## Removing non number charactors from emp_length column
#RawData_filter['emp_length'] = RawData_filter['emp_length'].replace({'10+':'10.5'},regex=True)
RawData_filter['emp_length'] = RawData_filter['emp_length'].replace({'< 1':'0.5'},regex=True)
RawData_filter['emp_length'] = RawData_filter['emp_length'].replace({'year':''},regex=True)
RawData_filter['emp_length'] = RawData_filter['emp_length'].replace({'s':''},regex=True)

## Removing non number charactors from int_rate & revol_util columns and converting loan_status to numberic
RawData_filter['int_rate'] = RawData_filter['int_rate'].replace({'%':''},regex=True)
RawData_filter['revol_util'] = RawData_filter['revol_util'].replace({'%':''},regex=True)
#RawData_filter['loan_status'] = RawData_filter['loan_status'].replace({'Fully Paid':'1'},regex=True)
#RawData_filter['loan_status'] = RawData_filter['loan_status'].replace({'Charged Off':'-1'},regex=True)
#RawData_filter['loan_status'] = RawData_filter['loan_status'].replace({'Current':'0'},regex=True)

## Replacing Blank employer name value with Unknown
RawData_filter['emp_title'] = RawData_filter['emp_title'].replace(np.nan, 'Unknown')
RawData_filter
# Out:
#          loan_status  loan_amnt  funded_amnt_inv  term grade int_rate  \
# id
# 1077501   Fully Paid       5000           4975.0   36      B    10.65
# 1077430  Charged Off       2500           2500.0   60      C    15.27
# 1077175   Fully Paid       2400           2400.0   36      C    15.96
# 1076863   Fully Paid      10000          10000.0   36      C    13.49
# 1075358      Current       3000           3000.0   60      B    12.69
# ...              ...        ...              ...   ...   ...      ...
# 92187     Fully Paid       2500           1075.0   36      A     8.07
# 90665     Fully Paid       8500            875.0   36      C    10.28
# 90395     Fully Paid       5000           1325.0   36      A     8.07
# 90376     Fully Paid       5000            650.0   36      A     7.43
# 87023     Fully Paid       7500            800.0   36      E    13.75
#
#          installment                   emp_title emp_length home_ownership  \
# id
# ...

# %% [markdown]
# # Below bar chart shows comparison between 'Not Verified' & 'Verified', the risk portion has been balanced.

# %%
## Checking the portion of money invested based on customer verification status.

Bar1 = RawData_Current_filter.groupby('verification_status')['funded_amnt_inv'].mean()
Bar1

plt.figure(); Bar1.plot.bar(title='SIMPLE BAR CHART (Mean Output – Verification_Status)', color='darkorange'); plt.xlabel('verification_status'); plt.ylabel('funded_amnt_inv')
# Out:
# Text(0, 0.5, 'funded_amnt_inv')

# %% [markdown]
# # Below Multiple Bar Chart has Loan distribution with home ownership vs experience.
# ## 1. The loan distribution is higher on people with Mortage, high risk.
# ### - Customer with existing obligation(Mortage), it puts additional burden to customer during repay.
# ## 2. Instead, we see there a huge opportunity space available on people with Own property.
# ### - They are always reachable as their properly state is stable.

# %%
Bar2=pd.pivot_table(RawData_Current_filter, index=['home_ownership'], columns=['emp_length'], values=['funded_amnt_inv'], aggfunc='mean')
Bar2

plt.figure(); Bar2.plot.bar(title='Home Ownership with Emp_length vs Loan Amount'); plt.xlabel('home_ownership'); plt.ylabel('emp_length')
# Out:
# Text(0, 0.5, 'emp_length')

# %% [markdown]
# # Geo Distribution of states shows, the majority of customers are in CA and organization should consider expanding in other states.

# %%
# Creating bar chart with status wise distribution

RawData_filter["addr_state"].value_counts().describe()
plt.figure(figsize = (16,6))

RawData_filter["addr_state"].value_counts()[RawData_filter["addr_state"].value_counts() > 117].plot.bar(align='center')

# Adding title & Axies
plt.title("Geo Distribution of Loans by States\n")
plt.xlabel("States")
plt.ylabel("Count")

plt.show()

## Checking the opportunity available in other states by income group

Bar3 = RawData_Current_filter.groupby('addr_state')['annual_inc'].mean()
Bar3

plt.figure(); Bar3.plot.bar(title='Income Group Vs States', color='yellow'); plt.xlabel('State'); plt.ylabel('Annual Income')
# Out:
# Text(0, 0.5, 'Annual Income')

# %% [markdown]
# # In Below chart, Risk proportion is visible as below
# ## - Loan for Car should be increased as it very less risky investment since car would be collateral.
#
# ## - CreditCard & DebtConsolidation, it should consider high risk as it indicates poor financial handling of the customer.
#
# ## - House should targeted as high as RenewalEnergy as collateral would be there.
#
# ## - Wedding & Medical should be considered high risk as there is no collateral in both and In Medical, if customer is taking treatment for self, there is high possibility of delay\drop in repay.

# %%
## Checking the portion of money invested based on customer verification status.

Bar4 = RawData_Current_filter.groupby('purpose')['funded_amnt_inv'].mean()
Bar4

plt.figure(); Bar4.plot.bar(title='Loan Distribution Vs Purpose', color='lightgreen'); plt.xlabel('Purpose'); plt.ylabel('Amount Invested')
# Out:
# Text(0, 0.5, 'Amount Invested')

# %% [markdown]
# # Box Plot of Income group indicate majority of customer's income is under "$ 100000"

# %%
# Creating Box plot to get the Income groups available

RawData_Current_filter["annual_inc"].plot.box(title='Income Groups Box Plot', figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'Income Groups Box Plot'}>

# %% [markdown]
# # Below Box Plot helps us comparing the historial data with current
# ## It is visible the Club has expanded distribution compared to historical loan data.

# %%
# Creating Box Plot on Loan Amount comparion with Loan Status

sns.boxplot(x="loan_status",y="loan_amnt", data=RawData_filter,palette="hls")
plt.xlabel("Loan status", fontsize=14)
plt.ylabel("Loan Amount", fontsize=14)
plt.title("Loan Amount and Loan Status", fontsize=20)

plt.show()

# %% [markdown]
# # Below comparision help us undertand folloings:
#
# ## 1. People with Own homes like to default very less.
# ## 2. People with Rent are high on risk.
# ## 3. Sales focus should be more on people with Property own followed by Mortages
# ## 4. Multiple sales techniques like lower interest rate should be used for people with own property to increase the loan distrubution in this section.

# %%
# Creating Count Plot Chart on HomeOwnership impact on Loan Status

sns.countplot(x="home_ownership" ,data=RawData_filter, hue="loan_status")
plt.xlabel("Home Ownership", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.title("Home Ownership Vs loan status", fontsize=20)

plt.show()

# %% [markdown]
# # Stacked Bar Chart shows comparison of experience aginst Loan status
# ## It indicates the default percentage ranges around 15% on all experience buckets.

# %%
# Creation of Stacked Bar Chart on Employment Experience impact on Loan Status

Stack2 = pd.crosstab(index=RawData_filter['emp_length'], columns=RawData_filter['loan_status'], normalize=0).reset_index()


axes = Stack2.set_index('emp_length').plot(kind='bar', stacked=True,)

fig = axes.get_figure()

for idx, row in Stack2.iterrows():
    plt.text(idx-.3, row['Charged Off']/3, "{:.0%}".format(row['Charged Off']))
for idx, row in Stack2.iterrows():
    plt.text(idx-.3, row['Fully Paid']/3, "{:.0%}".format(row['Fully Paid']))  
    
# Adjusting Label size
plt.xlabel("Employment Experience(Years)", fontsize=15)
plt.title("Employment Length Vs Loan Status", fontsize=20)
plt.show()
